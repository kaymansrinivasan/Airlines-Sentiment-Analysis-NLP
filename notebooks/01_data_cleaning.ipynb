# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\User\airline-sentiment\data\Airline Review.csv")
print(df.head())
# Out:
#    Unnamed: 0   Airline Name Overall_Rating  \
# 0           0    AB Aviation              9
# 1           1    AB Aviation              1
# 2           2    AB Aviation              1
# 3           3  Adria Airways              1
# 4           4  Adria Airways              1
#
#                             Review_Title          Review Date  Verified  \
# 0                "pretty decent airline"   11th November 2019      True
# 1                   "Not a good airline"       25th June 2019      True
# 2         "flight was fortunately short"       25th June 2019      True
# 3    "I will never fly again with Adria"  28th September 2019     False
# 4  "it ruined our last days of holidays"  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#        Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0   November 2019           4.0                  5.0               4.0
# 1       June 2019           2.0                  2.0               1.0
# 2       June 2019           2.0                  1.0               1.0
# 3  September 2019           1.0                  1.0               NaN
# 4  September 2019           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended
# 0              3.0         yes
# 1              2.0          no
# 2              2.0          no
# 3              1.0          no
# 4              1.0          no

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23171 entries, 0 to 23170
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              23171 non-null  int64
#  1   Airline Name            23171 non-null  str
#  2   Overall_Rating          23171 non-null  str
#  3   Review_Title            23171 non-null  str
#  4   Review Date             23171 non-null  str
#  5   Verified                23171 non-null  bool
#  6   Review                  23171 non-null  str
#  7   Aircraft                7129 non-null   str
#  8   Type Of Traveller       19433 non-null  str
#  9   Seat Type               22075 non-null  str
#  10  Route                   19343 non-null  str
#  11  Date Flown              19417 non-null  str
#  12  Seat Comfort            19016 non-null  float64
#  13  Cabin Staff Service     18911 non-null  float64
#  14  Food & Beverages        14500 non-null  float64
#  15  Ground Service          18378 non-null  float64
#  16  Inflight Entertainment  10829 non-null  float64
#  17  Wifi & Connectivity     5920 non-null   float64
#  18  Value For Money         22105 non-null  float64
#  19  Recommended             23171 non-null  str
# dtypes: bool(1), float64(7), int64(1), str(11)
# memory usage: 21.9 MB

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.drop(columns=['Aircraft'], inplace=True)

# %%
df["Overall_Rating"] = pd.to_numeric(df["Overall_Rating"], errors='coerce')
df['Review Date'] = (
    df['Review Date']
    .str.strip()
    .str.replace(r'(\d{1,2})(st|nd|rd|th)', r'\1', regex=True)
)

df['Review Date'] = pd.to_datetime(
    df['Review Date'],
    format='%d %B %Y',
    errors='coerce'
)

df['Date Flown'] = pd.to_datetime(
    df['Date Flown'].astype(str).str.strip(),
    format='%B %Y',
    errors='coerce'
)

# %%
print(df['Review Date'].dropna().head(10).tolist())
# Out:
# [Timestamp('2019-11-11 00:00:00'), Timestamp('2019-06-25 00:00:00'), Timestamp('2019-06-25 00:00:00'), Timestamp('2019-09-28 00:00:00'), Timestamp('2019-09-24 00:00:00'), Timestamp('2019-09-17 00:00:00'), Timestamp('2019-09-06 00:00:00'), Timestamp('2019-08-24 00:00:00'), Timestamp('2019-08-06 00:00:00'), Timestamp('2018-10-12 00:00:00')]

# %%
print(df['Date Flown'].dropna().head(10).tolist())
# Out:
# [Timestamp('2019-11-01 00:00:00'), Timestamp('2019-06-01 00:00:00'), Timestamp('2019-06-01 00:00:00'), Timestamp('2019-09-01 00:00:00'), Timestamp('2019-09-01 00:00:00'), Timestamp('2019-09-01 00:00:00'), Timestamp('2019-09-01 00:00:00'), Timestamp('2019-08-01 00:00:00'), Timestamp('2019-08-01 00:00:00'), Timestamp('2018-10-01 00:00:00')]

# %%
print(df.isna().sum())
# Out:
# Airline Name                  0
# Overall_Rating              842
# Review_Title                  0
# Review Date                   0
# Verified                      0
# Review                        0
# Type Of Traveller          3738
# Seat Type                  1096
# Route                      3828
# Date Flown                 3754
# Seat Comfort               4155
# Cabin Staff Service        4260
# Food & Beverages           8671
# Ground Service             4793
# Inflight Entertainment    12342
# Wifi & Connectivity       17251
# Value For Money            1066
# Recommended                   0
# dtype: int64

# %%
df = df.dropna(subset=['Overall_Rating'])
print(df.isna().sum())
# Out:
# Airline Name                  0
# Overall_Rating                0
# Review_Title                  0
# Review Date                   0
# Verified                      0
# Review                        0
# Type Of Traveller          2896
# Seat Type                   568
# Route                      2986
# Date Flown                 2912
# Seat Comfort               3490
# Cabin Staff Service        3595
# Food & Beverages           8006
# Ground Service             3951
# Inflight Entertainment    11676
# Wifi & Connectivity       16409
# Value For Money             541
# Recommended                   0
# dtype: int64

# %%
aspect_cols = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
               'Ground Service', 'Value For Money']
df[aspect_cols] = df[aspect_cols].fillna(df[aspect_cols].median())

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Wifi & Connectivity       16409
# Inflight Entertainment    11676
# Route                      2986
# Date Flown                 2912
# Type Of Traveller          2896
# Seat Type                   568
# Overall_Rating                0
# Airline Name                  0
# Review                        0
# Verified                      0
# Review_Title                  0
# Review Date                   0
# Seat Comfort                  0
# Cabin Staff Service           0
# Ground Service                0
# Food & Beverages              0
# Value For Money               0
# Recommended                   0
# dtype: int64

# %%
df['Type Of Traveller'] = df['Type Of Traveller'].fillna('Unknown')
df['Seat Type'] = df['Seat Type'].fillna('Unknown')
df['Route'] = df['Route'].fillna('Unknown')

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Wifi & Connectivity       16409
# Inflight Entertainment    11676
# Date Flown                 2912
# Airline Name                  0
# Overall_Rating                0
# Review_Title                  0
# Review                        0
# Type Of Traveller             0
# Verified                      0
# Review Date                   0
# Route                         0
# Seat Type                     0
# Seat Comfort                  0
# Cabin Staff Service           0
# Ground Service                0
# Food & Beverages              0
# Value For Money               0
# Recommended                   0
# dtype: int64

# %%
df["Wifi & Connectivity"].value_counts().sort_values()
# Out:
# Wifi & Connectivity
# 0.0       1
# 4.0     400
# 2.0     479
# 3.0     487
# 5.0     492
# 1.0    4061
# Name: count, dtype: int64

# %%
df.drop(columns=['Wifi & Connectivity'], inplace=True)

# %%
df["Inflight Entertainment"].value_counts().sort_values()
# Out:
# Inflight Entertainment
# 0.0     422
# 5.0    1156
# 2.0    1271
# 4.0    1325
# 3.0    1692
# 1.0    4787
# Name: count, dtype: int64

# %%
df.drop(columns=['Inflight Entertainment'], inplace=True)

# %%
df.isna().sum().sort_values(ascending=False)#Date Flown is left in the special case
# Out:
# Date Flown             2912
# Airline Name              0
# Review_Title              0
# Overall_Rating            0
# Verified                  0
# Review                    0
# Type Of Traveller         0
# Review Date               0
# Seat Type                 0
# Route                     0
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Ground Service            0
# Value For Money           0
# Recommended               0
# dtype: int64

# %%
print(df.shape)
df.info()
# Out:
# (22329, 16)
# <class 'pandas.DataFrame'>
# Index: 22329 entries, 0 to 23170
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Airline Name         22329 non-null  str
#  1   Overall_Rating       22329 non-null  float64
#  2   Review_Title         22329 non-null  str
#  3   Review Date          22329 non-null  datetime64[us]
#  4   Verified             22329 non-null  bool
#  5   Review               22329 non-null  str
#  6   Type Of Traveller    22329 non-null  str
#  7   Seat Type            22329 non-null  str
#  8   Route                22329 non-null  str
#  9   Date Flown           19417 non-null  datetime64[us]
#  10  Seat Comfort         22329 non-null  float64
#  11  Cabin Staff Service  22329 non-null  float64
#  12  Food & Beverages     22329 non-null  float64
#  13  Ground Service       22329 non-null  float64
#  14  Value For Money      22329 non-null  float64
#  15  Recommended          22329 non-null  str
# dtypes: bool(1), datetime64[us](2), float64(6), str(7)
# memory usage: 20.1 MB

# %%
print(df.head())
# Out:
#     Airline Name  Overall_Rating                           Review_Title  \
# 0    AB Aviation             9.0                "pretty decent airline"
# 1    AB Aviation             1.0                   "Not a good airline"
# 2    AB Aviation             1.0         "flight was fortunately short"
# 3  Adria Airways             1.0    "I will never fly again with Adria"
# 4  Adria Airways             1.0  "it ruined our last days of holidays"
#
#   Review Date  Verified                                             Review  \
# 0  2019-11-11      True    Moroni to Moheli. Turned out to be a pretty ...
# 1  2019-06-25      True   Moroni to Anjouan. It is a very small airline...
# 2  2019-06-25      True    Anjouan to Dzaoudzi. A very small airline an...
# 3  2019-09-28     False    Please do a favor yourself and do not fly wi...
# 4  2019-09-24      True   Do not book a flight with this airline! My fr...
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#   Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0 2019-11-01           4.0                  5.0               4.0
# 1 2019-06-01           2.0                  2.0               1.0
# 2 2019-06-01           2.0                  1.0               1.0
# 3 2019-09-01           1.0                  1.0               2.0
# 4 2019-09-01           1.0                  1.0               1.0
#
#    Ground Service  Value For Money Recommended
# 0             4.0              3.0         yes
# 1             1.0              2.0          no
# 2             1.0              2.0          no
# 3             1.0              1.0          no
# 4             1.0              1.0          no

# %%
def rating_to_sentiment(r):
    if r <= 4: return 'negative'
    elif r <= 6: return 'neutral'
    else: return 'positive'

df['sentiment'] = df['Overall_Rating'].apply(rating_to_sentiment)

# %%
df['label'] = df['sentiment'].map({
    'negative': 0,
    'neutral': 1,
    'positive': 2
})

# %%
df['full_text'] = df['Review_Title'] + " " + df['Review']

# %%
df['recommended_binary'] = df['Recommended'].str.lower().map({
    'yes': 1,
    'no': 0
})

# %%
df['Review_Title'] = df['Review_Title'].str.replace('"', '').str.strip()
df['Review'] = df['Review'].str.replace('"', '').str.strip()

# %%
df[['sentiment', 'label']]
# Out:
#       sentiment  label
# 0      positive      2
# 1      negative      0
# 2      negative      0
# 3      negative      0
# 4      negative      0
# ...         ...    ...
# 23166  negative      0
# 23167  negative      0
# 23168  negative      0
# 23169   neutral      1
# 23170  negative      0
#
# [22329 rows x 2 columns]

# %%
df['sentiment'].value_counts(normalize=True)
# Out:
# sentiment
# negative    0.721304
# positive    0.211295
# neutral     0.067401
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# Airline Name              0
# Overall_Rating            0
# Review_Title              0
# Review Date               0
# Verified                  0
# Review                    0
# Type Of Traveller         0
# Seat Type                 0
# Route                     0
# Date Flown             2912
# Seat Comfort              0
# Cabin Staff Service       0
# Food & Beverages          0
# Ground Service            0
# Value For Money           0
# Recommended               0
# sentiment                 0
# label                     0
# full_text                 0
# recommended_binary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 22329 entries, 0 to 23170
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Airline Name         22329 non-null  str
#  1   Overall_Rating       22329 non-null  float64
#  2   Review_Title         22329 non-null  str
#  3   Review Date          22329 non-null  datetime64[us]
#  4   Verified             22329 non-null  bool
#  5   Review               22329 non-null  str
#  6   Type Of Traveller    22329 non-null  str
#  7   Seat Type            22329 non-null  str
#  8   Route                22329 non-null  str
#  9   Date Flown           19417 non-null  datetime64[us]
#  10  Seat Comfort         22329 non-null  float64
#  11  Cabin Staff Service  22329 non-null  float64
#  12  Food & Beverages     22329 non-null  float64
#  13  Ground Service       22329 non-null  float64
#  14  Value For Money      22329 non-null  float64
#  15  Recommended          22329 non-null  str
#  16  sentiment            22329 non-null  str
#  17  label                22329 non-null  int64
#  18  full_text            22329 non-null  str
#  19  recommended_binary   22329 non-null  int64
# dtypes: bool(1), datetime64[us](2), float64(6), int64(2), str(9)
# memory usage: 36.9 MB

# %%
df['Review_Title'] = df['Review_Title'].str.replace('"', '').str.strip()
df['Review'] = df['Review'].str.replace('"', '').str.strip()
